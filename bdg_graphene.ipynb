# %%
from quant_met import plotting, hamiltonians, utils
import numpy as np
import time
import matplotlib.pyplot as plt
import pandas as pd

# %%
lattice_constant = np.sqrt(3)

all_K_points = 4 * np.pi / (3 * lattice_constant) * np.array([
    (np.sin(i * np.pi / 6), np.cos(i * np.pi / 6)) for i in [1, 3, 5, 7, 9, 11]]
)

Gamma = np.array([0, 0])
M = np.pi / lattice_constant * np.array([1, 1 / np.sqrt(3)])
K = 4 * np.pi / (3 * lattice_constant) * np.array([1, 0])

points = [(M, 'M'), (Gamma, r'\Gamma'), (all_K_points[1], 'K')]

band_path, band_path_plot, ticks, labels = plotting.generate_bz_path(points, number_of_points=1000)

#BZ_path_plot = plotting.scatter_into_bz(all_K_points, band_path)

graphene_h = hamiltonians.GrapheneHamiltonian(t_nn=1, a=lattice_constant, mu=0, coulomb_gr=1)

band_structure = graphene_h.calculate_bandstructure(band_path)

BZ_grid = utils.generate_uniform_grid(20, 20, all_K_points[1], all_K_points[5], origin=np.array([0, 0]))

# %%
gap_size_vs_U = pd.DataFrame()

U_range = np.linspace(start=0.1, stop=6, num=10)

gap_size_vs_U['U'] = U_range

for mu in [0, 0.5, 1, 1.5, 2]:
    delta_over_U = []
    beta = 1000

    for i, U in enumerate(U_range):
        graphene_h = hamiltonians.GrapheneHamiltonian(t_nn=1, a=lattice_constant, mu=mu, coulomb_gr=U)

        start = time.time()
        solution = hamiltonians.minimize_loop(beta=None, k_points=BZ_grid, hamiltonian=graphene_h)
        print(f'mu = {mu}, U = {U}, solution: {solution}')
        end = time.time()
        print(f'Time taken to solve the gap equation: {end - start:0.2f} seconds')
        gap_size_vs_U.loc[i, f'{mu}'] = solution[0]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      12 graphene_h = hamiltonians.GrapheneHamiltonian(t_nn=1, a=lattice_constant, mu=mu, coulomb_gr=U)
#      14 start = time.time()
# ---> 15 solution = hamiltonians.minimize_loop(beta=None, k_points=BZ_grid, hamiltonian=graphene_h)
#      16 print(f'mu = {mu}, U = {U}, solution: {solution}')
#      17 end = time.time()
#
# File ~/Projects/quant-met/src/quant_met/hamiltonians/_free_energy.py:13, in minimize_loop(hamiltonian, k_points, beta)
#       8 def minimize_loop(
#       9     hamiltonian: BaseHamiltonian,
#      10     k_points: npt.NDArray[np.float64],
#      11     beta: float | None = None,
#      12 ) -> npt.NDArray[np.float64]:
# ---> 13     solution = optimize.brute(
#      14         func=free_energy,
#      15         args=(
#      16             hamiltonian,
#      17             k_points,
#      18             beta,
#      19         ),
#      20         ranges=[(0, 1) for _ in range(hamiltonian.number_of_bands)],
#      21         Ns=20,
#      22         workers=10,
#      23         finish=optimize.fmin,
#      24         full_output=True,
#      25     )
#      27     delta_solution: npt.NDArray[np.float64] = solution[0]
#      29     hamiltonian.delta_orbital_basis = delta_solution
#
# File ~/miniconda3/envs/quant-met-dev/lib/python3.12/site-packages/scipy/optimize/_optimize.py:3798, in brute(func, ranges, args, Ns, full_output, finish, disp, workers)
#    3796 # iterate over input arrays, possibly in parallel
#    3797 with MapWrapper(pool=workers) as mapper:
# -> 3798     Jout = np.array(list(mapper(wrapped_func, grid)))
#    3799     if (N == 1):
#    3800         grid = (grid,)
#
# File ~/miniconda3/envs/quant-met-dev/lib/python3.12/site-packages/scipy/_lib/_util.py:511, in MapWrapper.__call__(self, func, iterable)
#     508 def __call__(self, func, iterable):
#     509     # only accept one iterable because that's all Pool.map accepts
#     510     try:
# --> 511         return self._mapfunc(func, iterable)
#     512     except TypeError as e:
#     513         # wrong number of arguments
#     514         raise TypeError("The map-like callable must be of the"
#     515                         " form f(func, iterable)") from e
#
# File ~/miniconda3/envs/quant-met-dev/lib/python3.12/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/envs/quant-met-dev/lib/python3.12/multiprocessing/pool.py:768, in ApplyResult.get(self, timeout)
#     767 def get(self, timeout=None):
# --> 768     self.wait(timeout)
#     769     if not self.ready():
#     770         raise TimeoutError
#
# File ~/miniconda3/envs/quant-met-dev/lib/python3.12/multiprocessing/pool.py:765, in ApplyResult.wait(self, timeout)
#     764 def wait(self, timeout=None):
# --> 765     self._event.wait(timeout)
#
# File ~/miniconda3/envs/quant-met-dev/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniconda3/envs/quant-met-dev/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
graphene_h = hamiltonians.GrapheneHamiltonian(t_nn=1, a=lattice_constant, mu=-1, coulomb_gr=4)
solution = hamiltonians.minimize_loop(beta=None, k_points=BZ_grid, hamiltonian=graphene_h)
print(graphene_h.delta_orbital_basis)
graphene_h.save('test.hdf5')
# Out:
# [1.35682297 1.35681788]

# %%
graphene_h = hamiltonians.GrapheneHamiltonian.from_file('test.hdf5')
print(graphene_h.delta_orbital_basis)
# Out:
# [1.35682297 1.35681788]

# %%
fig, ax= plt.subplots()

for mu in [0, 0.5, 1, 1.5, 2]:
    #print(gap_size_vs_U[f'{mu}'])
    ax.plot(gap_size_vs_U['U'], gap_size_vs_U[f'{mu}'], 'x--', label=f'{mu}', alpha=0.9)

plt.ylim(bottom=0)
plt.xlim(left=0, right=6)
plt.ylabel("Gap/t")
plt.legend()
