# %%
from quant_met import hamiltonians, utils, plotting
import numpy as np
import pandas as pd
import time

# %%
lattice_constant = np.sqrt(3)

all_K_points = 4 * np.pi / (3 * lattice_constant) * np.array([
    (np.sin(i * np.pi / 6), np.cos(i * np.pi / 6)) for i in [1, 3, 5, 7, 9, 11]]
)

Gamma = np.array([0, 0])
M = np.pi / lattice_constant * np.array([1, 1 / np.sqrt(3)])
K = 4 * np.pi / (3 * lattice_constant) * np.array([1, 0])

points = [(M, 'M'), (Gamma, r'\Gamma'), (all_K_points[1], 'K')]

band_path, band_path_plot, ticks, labels = plotting.generate_bz_path(points, number_of_points=1000)

#BZ_path_plot = plotting.scatter_into_bz(all_K_points, band_path)

BZ_grid = utils.generate_uniform_grid(8, 8, all_K_points[1], all_K_points[5], origin=np.array([0, 0]))

# %%
U_range = np.linspace(start=0.1, stop=6, num=10)

for V in [0.1, 1, 2]:
    for mu in [0, -0.5, -1, -1.5, -2]:
        gap_size_vs_U = pd.DataFrame(columns=['U', 'delta_0', 'delta_1', 'delta_2'], index=range(len(U_range)))
        gap_size_vs_U['U'] = U_range

        for i, U in enumerate(U_range):
            egx_h = hamiltonians.EGXHamiltonian(t_gr=1, t_x=0.01, a=lattice_constant, V=V, mu=mu, U_gr=U, U_x=U)

            start = time.time()
            solution = hamiltonians.minimize_loop(beta=None, k_points=BZ_grid, hamiltonian=egx_h)
            print(f'mu = {mu}, U = {U}, solution: {solution}')
            end = time.time()
            print(f'Time taken to solve the gap equation: {end - start:0.2f} seconds')
            gap_size_vs_U.loc[i, ['delta_0', 'delta_1', 'delta_2']] = solution
        
        gap_size_vs_U.to_csv(f'gap_plots/gap_size_vs_U_V_{V}_mu_{mu}.csv')
# Out:
# mu = 0, U = 0.1, solution: [0.00053951 0.0024736  0.0419253 ]
# Time taken to solve the gap equation: 10.37 seconds
# mu = 0, U = 0.7555555555555555, solution: [0.02079308 0.0231631  0.37343602]
# Time taken to solve the gap equation: 10.65 seconds
# mu = 0, U = 1.4111111111111112, solution: [0.05522695 0.0567266  0.70210594]
# Time taken to solve the gap equation: 9.74 seconds
# mu = 0, U = 2.066666666666667, solution: [0.12028889 0.12159336 1.03033271]
# Time taken to solve the gap equation: 9.69 seconds
# mu = 0, U = 2.7222222222222223, solution: [0.33139446 0.33309478 1.35827618]
# Time taken to solve the gap equation: 10.00 seconds
# mu = 0, U = 3.3777777777777778, solution: [1.02680451 1.02931782 1.68614453]
# Time taken to solve the gap equation: 10.10 seconds
# mu = 0, U = 4.033333333333333, solution: [1.46644848 1.4687016  2.01422362]
# Time taken to solve the gap equation: 9.96 seconds
# mu = 0, U = 4.688888888888888, solution: [1.85630026 1.85828092 2.34232142]
# Time taken to solve the gap equation: 10.02 seconds
# mu = 0, U = 5.344444444444444, solution: [2.2310985  2.23281055 2.6703136 ]
# Time taken to solve the gap equation: 10.25 seconds
# mu = 0, U = 6.0, solution: [2.59743838 2.59900018 2.99827923]
# Time taken to solve the gap equation: 9.95 seconds
# mu = -0.5, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.06 seconds
# mu = -0.5, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.14 seconds
# mu = -0.5, U = 1.4111111111111112, solution: [0.04058929 0.02441761 0.49246211]
# Time taken to solve the gap equation: 10.12 seconds
# mu = -0.5, U = 2.066666666666667, solution: [0.15865521 0.15143167 0.90016485]
# Time taken to solve the gap equation: 10.21 seconds
# mu = -0.5, U = 2.7222222222222223, solution: [0.54017246 0.54020716 1.26247345]
# Time taken to solve the gap equation: 9.94 seconds
# mu = -0.5, U = 3.3777777777777778, solution: [1.041201   1.04282986 1.6102581 ]
# Time taken to solve the gap equation: 10.59 seconds
# mu = -0.5, U = 4.033333333333333, solution: [1.45040174 1.452131   1.95115723]
# Time taken to solve the gap equation: 10.49 seconds
# mu = -0.5, U = 4.688888888888888, solution: [1.83469268 1.83634198 2.28821249]
# Time taken to solve the gap equation: 11.08 seconds
# mu = -0.5, U = 5.344444444444444, solution: [2.20796405 2.20955415 2.62298801]
# Time taken to solve the gap equation: 10.33 seconds
# mu = -0.5, U = 6.0, solution: [2.57415618 2.57563769 2.95616228]
# Time taken to solve the gap equation: 10.00 seconds
# mu = -1, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.74 seconds
# mu = -1, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.95 seconds
# mu = -1, U = 1.4111111111111112, solution: [0.09553871 0.09288173 0.00218221]
# Time taken to solve the gap equation: 10.68 seconds
# mu = -1, U = 2.066666666666667, solution: [0.33225785 0.32807024 0.27447914]
# Time taken to solve the gap equation: 10.55 seconds
# mu = -1, U = 2.7222222222222223, solution: [0.65342392 0.65146085 0.92156042]
# Time taken to solve the gap equation: 9.55 seconds
# mu = -1, U = 3.3777777777777778, solution: [1.01808787 1.01784352 1.35874919]
# Time taken to solve the gap equation: 10.14 seconds
# mu = -1, U = 4.033333333333333, solution: [1.39333249 1.39391673 1.74908124]
# Time taken to solve the gap equation: 9.92 seconds
# mu = -1, U = 4.688888888888888, solution: [1.76745895 1.76833391 2.11829594]
# Time taken to solve the gap equation: 9.87 seconds
# mu = -1, U = 5.344444444444444, solution: [2.13748505 2.13853357 2.47609199]
# Time taken to solve the gap equation: 10.21 seconds
# mu = -1, U = 6.0, solution: [2.50322324 2.50426649 2.82657729]
# Time taken to solve the gap equation: 10.91 seconds
# mu = -1.5, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.00 seconds
# mu = -1.5, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.46 seconds
# mu = -1.5, U = 1.4111111111111112, solution: [0.07627579 0.07589211 0.00045154]
# Time taken to solve the gap equation: 9.69 seconds
# mu = -1.5, U = 2.066666666666667, solution: [0.28425798 0.28310752 0.00267359]
# Time taken to solve the gap equation: 10.22 seconds
# mu = -1.5, U = 2.7222222222222223, solution: [0.58416074 0.58228595 0.01585486]
# Time taken to solve the gap equation: 10.26 seconds
# mu = -1.5, U = 3.3777777777777778, solution: [0.92566841 0.92388823 0.77895714]
# Time taken to solve the gap equation: 10.15 seconds
# mu = -1.5, U = 4.033333333333333, solution: [1.28404358 1.28312162 1.34717644]
# Time taken to solve the gap equation: 10.12 seconds
# mu = -1.5, U = 4.688888888888888, solution: [1.64906088 1.6488847  1.80029068]
# Time taken to solve the gap equation: 10.40 seconds
# mu = -1.5, U = 5.344444444444444, solution: [2.01567755 2.0159355  2.20992474]
# Time taken to solve the gap equation: 10.53 seconds
# mu = -1.5, U = 6.0, solution: [2.38132656 2.38185592 2.59637651]
# Time taken to solve the gap equation: 10.61 seconds
# mu = -2, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.46 seconds
# mu = -2, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.98 seconds
# mu = -2, U = 1.4111111111111112, solution: [0.06422145 0.064129   0.00018074]
# Time taken to solve the gap equation: 10.06 seconds
# mu = -2, U = 2.066666666666667, solution: [0.21123577 0.21073463 0.00078487]
# Time taken to solve the gap equation: 11.32 seconds
# mu = -2, U = 2.7222222222222223, solution: [4.67465639e-01 4.66256222e-01 3.10586650e-04]
# Time taken to solve the gap equation: 10.48 seconds
# mu = -2, U = 3.3777777777777778, solution: [0.77887546 0.77735595 0.00729201]
# Time taken to solve the gap equation: 10.47 seconds
# mu = -2, U = 4.033333333333333, solution: [1.11818186 1.11643949 0.3165962 ]
# Time taken to solve the gap equation: 10.15 seconds
# mu = -2, U = 4.688888888888888, solution: [1.47289008 1.47155796 1.22455873]
# Time taken to solve the gap equation: 10.20 seconds
# mu = -2, U = 5.344444444444444, solution: [1.83577597 1.83499225 1.77161933]
# Time taken to solve the gap equation: 10.00 seconds
# mu = -2, U = 6.0, solution: [2.20231994 2.2019881  2.23490986]
# Time taken to solve the gap equation: 10.26 seconds
# mu = 0, U = 0.1, solution: [0.00022799 0.01551909 0.021554  ]
# Time taken to solve the gap equation: 9.92 seconds
# mu = 0, U = 0.7555555555555555, solution: [0.02072065 0.13706027 0.23404546]
# Time taken to solve the gap equation: 10.21 seconds
# mu = 0, U = 1.4111111111111112, solution: [0.08835751 0.28203976 0.48009747]
# Time taken to solve the gap equation: 9.54 seconds
# mu = 0, U = 2.066666666666667, solution: [0.23728548 0.48471468 0.76169036]
# Time taken to solve the gap equation: 10.05 seconds
# mu = 0, U = 2.7222222222222223, solution: [0.51304688 0.78179629 1.0786716 ]
# Time taken to solve the gap equation: 10.16 seconds
# mu = 0, U = 3.3777777777777778, solution: [0.88877256 1.14183043 1.42808082]
# Time taken to solve the gap equation: 10.22 seconds
# mu = 0, U = 4.033333333333333, solution: [1.28849087 1.51364135 1.7867715 ]
# Time taken to solve the gap equation: 11.05 seconds
# mu = 0, U = 4.688888888888888, solution: [1.68415831 1.8834583  2.14204138]
# Time taken to solve the gap equation: 9.75 seconds
# mu = 0, U = 5.344444444444444, solution: [2.07128647 2.24905823 2.49242208]
# Time taken to solve the gap equation: 9.95 seconds
# mu = 0, U = 6.0, solution: [2.45028042 2.61035948 2.83853642]
# Time taken to solve the gap equation: 10.44 seconds
# mu = -0.5, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.86 seconds
# mu = -0.5, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 10.00 seconds
# mu = -0.5, U = 1.4111111111111112, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.32 seconds
# mu = -0.5, U = 2.066666666666667, solution: [0.18197485 0.25392395 0.53241129]
# Time taken to solve the gap equation: 9.87 seconds
# mu = -0.5, U = 2.7222222222222223, solution: [0.51232542 0.67003239 0.9810145 ]
# Time taken to solve the gap equation: 9.70 seconds
# mu = -0.5, U = 3.3777777777777778, solution: [0.90114075 1.08863172 1.3734263 ]
# Time taken to solve the gap equation: 10.07 seconds
# mu = -0.5, U = 4.033333333333333, solution: [1.29146442 1.47662424 1.74355717]
# Time taken to solve the gap equation: 10.72 seconds
# mu = -0.5, U = 4.688888888888888, solution: [1.67859004 1.85229431 2.10334643]
# Time taken to solve the gap equation: 11.15 seconds
# mu = -0.5, U = 5.344444444444444, solution: [2.06024082 2.2207822  2.45652836]
# Time taken to solve the gap equation: 11.31 seconds
# mu = -0.5, U = 6.0, solution: [2.43597021 2.58393297 2.80508762]
# Time taken to solve the gap equation: 10.48 seconds
# mu = -1, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.18 seconds
# mu = -1, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 11.21 seconds
# mu = -1, U = 1.4111111111111112, solution: [0.06465067 0.01664047 0.07022111]
# Time taken to solve the gap equation: 10.56 seconds
# mu = -1, U = 2.066666666666667, solution: [0.2412398  0.12452546 0.30219725]
# Time taken to solve the gap equation: 10.28 seconds
# mu = -1, U = 2.7222222222222223, solution: [0.57401846 0.50018742 0.77296583]
# Time taken to solve the gap equation: 10.60 seconds
# mu = -1, U = 3.3777777777777778, solution: [0.93277056 0.96114058 1.21550751]
# Time taken to solve the gap equation: 9.75 seconds
# mu = -1, U = 4.033333333333333, solution: [1.291542   1.37208233 1.60816196]
# Time taken to solve the gap equation: 10.08 seconds
# mu = -1, U = 4.688888888888888, solution: [1.65647031 1.75973509 1.98146643]
# Time taken to solve the gap equation: 10.22 seconds
# mu = -1, U = 5.344444444444444, solution: [2.02394205 2.13555248 2.34484849]
# Time taken to solve the gap equation: 10.06 seconds
# mu = -1, U = 6.0, solution: [2.39100829 2.50378044 2.70186592]
# Time taken to solve the gap equation: 9.90 seconds
# mu = -1.5, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.45 seconds
# mu = -1.5, U = 0.7555555555555555, solution: [7.46527778e-05 3.29861111e-05 6.77083333e-05]
# Time taken to solve the gap equation: 9.68 seconds
# mu = -1.5, U = 1.4111111111111112, solution: [0.14663447 0.06655636 0.08636324]
# Time taken to solve the gap equation: 10.41 seconds
# mu = -1.5, U = 2.066666666666667, solution: [0.36785965 0.20604037 0.26441569]
# Time taken to solve the gap equation: 9.69 seconds
# mu = -1.5, U = 2.7222222222222223, solution: [0.64205497 0.46286528 0.5655454 ]
# Time taken to solve the gap equation: 9.65 seconds
# mu = -1.5, U = 3.3777777777777778, solution: [0.94481072 0.82316227 0.9567011 ]
# Time taken to solve the gap equation: 9.45 seconds
# mu = -1.5, U = 4.033333333333333, solution: [1.26803557 1.21803788 1.36487204]
# Time taken to solve the gap equation: 10.57 seconds
# mu = -1.5, U = 4.688888888888888, solution: [1.60685439 1.60989485 1.76174889]
# Time taken to solve the gap equation: 10.18 seconds
# mu = -1.5, U = 5.344444444444444, solution: [1.95603612 1.99281296 2.14581653]
# Time taken to solve the gap equation: 10.55 seconds
# mu = -1.5, U = 6.0, solution: [2.31114231 2.36805522 2.52021816]
# Time taken to solve the gap equation: 10.57 seconds
# mu = -2, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.35 seconds
# mu = -2, U = 0.7555555555555555, solution: [0.01439409 0.01063085 0.00398324]
# Time taken to solve the gap equation: 10.05 seconds
# mu = -2, U = 1.4111111111111112, solution: [0.05752958 0.0420089  0.01817074]
# Time taken to solve the gap equation: 10.43 seconds
# mu = -2, U = 2.066666666666667, solution: [0.24474774 0.17725422 0.09267682]
# Time taken to solve the gap equation: 10.30 seconds
# mu = -2, U = 2.7222222222222223, solution: [0.54211226 0.40449987 0.26363038]
# Time taken to solve the gap equation: 10.26 seconds
# mu = -2, U = 3.3777777777777778, solution: [0.86481901 0.69317871 0.56409948]
# Time taken to solve the gap equation: 10.03 seconds
# mu = -2, U = 4.033333333333333, solution: [1.18640711 1.03586422 0.97505007]
# Time taken to solve the gap equation: 9.63 seconds
# mu = -2, U = 4.688888888888888, solution: [1.51097584 1.4093694  1.41152436]
# Time taken to solve the gap equation: 10.09 seconds
# mu = -2, U = 5.344444444444444, solution: [1.84503365 1.79170756 1.83534248]
# Time taken to solve the gap equation: 10.04 seconds
# mu = -2, U = 6.0, solution: [2.18865161 2.1730075  2.24247342]
# Time taken to solve the gap equation: 10.39 seconds
# mu = 0, U = 0.1, solution: [0.00020835 0.03138801 0.011524  ]
# Time taken to solve the gap equation: 10.70 seconds
# mu = 0, U = 0.7555555555555555, solution: [0.01174919 0.26126731 0.11295636]
# Time taken to solve the gap equation: 10.44 seconds
# mu = 0, U = 1.4111111111111112, solution: [0.04615495 0.50756333 0.22298373]
# Time taken to solve the gap equation: 10.01 seconds
# mu = 0, U = 2.066666666666667, solution: [0.1135474  0.76987361 0.35328105]
# Time taken to solve the gap equation: 9.45 seconds
# mu = 0, U = 2.7222222222222223, solution: [0.23230291 1.04651563 0.52350396]
# Time taken to solve the gap equation: 9.46 seconds
# mu = 0, U = 3.3777777777777778, solution: [0.43155094 1.3366306  0.76333571]
# Time taken to solve the gap equation: 9.70 seconds
# mu = 0, U = 4.033333333333333, solution: [0.73594953 1.64245658 1.09408934]
# Time taken to solve the gap equation: 10.21 seconds
# mu = 0, U = 4.688888888888888, solution: [1.12419231 1.9664048  1.49082955]
# Time taken to solve the gap equation: 9.85 seconds
# mu = 0, U = 5.344444444444444, solution: [1.54512145 2.30387418 1.9055017 ]
# Time taken to solve the gap equation: 9.79 seconds
# mu = 0, U = 6.0, solution: [1.96736085 2.64817555 2.31346559]
# Time taken to solve the gap equation: 9.92 seconds
# mu = -0.5, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 8.93 seconds
# mu = -0.5, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 8.95 seconds
# mu = -0.5, U = 1.4111111111111112, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.24 seconds
# mu = -0.5, U = 2.066666666666667, solution: [0.06962602 0.46703071 0.19926987]
# Time taken to solve the gap equation: 9.50 seconds
# mu = -0.5, U = 2.7222222222222223, solution: [0.20225946 0.86105299 0.42756995]
# Time taken to solve the gap equation: 9.56 seconds
# mu = -0.5, U = 3.3777777777777778, solution: [0.42386125 1.2113862  0.7115521 ]
# Time taken to solve the gap equation: 10.34 seconds
# mu = -0.5, U = 4.033333333333333, solution: [0.75294587 1.55722478 1.07812907]
# Time taken to solve the gap equation: 10.98 seconds
# mu = -0.5, U = 4.688888888888888, solution: [1.14960869 1.90688523 1.48938183]
# Time taken to solve the gap equation: 10.81 seconds
# mu = -0.5, U = 5.344444444444444, solution: [1.56564932 2.25925939 1.90397922]
# Time taken to solve the gap equation: 11.70 seconds
# mu = -0.5, U = 6.0, solution: [1.97964165 2.61197257 2.30792658]
# Time taken to solve the gap equation: 10.73 seconds
# mu = -1, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.45 seconds
# mu = -1, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.16 seconds
# mu = -1, U = 1.4111111111111112, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.12 seconds
# mu = -1, U = 2.066666666666667, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.93 seconds
# mu = -1, U = 2.7222222222222223, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.61 seconds
# mu = -1, U = 3.3777777777777778, solution: [0.36958724 0.76937461 0.52473624]
# Time taken to solve the gap equation: 10.13 seconds
# mu = -1, U = 4.033333333333333, solution: [0.80816288 1.3088513  1.03827074]
# Time taken to solve the gap equation: 9.84 seconds
# mu = -1, U = 4.688888888888888, solution: [1.21858779 1.73752767 1.48024694]
# Time taken to solve the gap equation: 10.52 seconds
# mu = -1, U = 5.344444444444444, solution: [1.61629373 2.12944616 1.89030161]
# Time taken to solve the gap equation: 10.15 seconds
# mu = -1, U = 6.0, solution: [2.00796097 2.50448204 2.28377062]
# Time taken to solve the gap equation: 11.01 seconds
# mu = -1.5, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.42 seconds
# mu = -1.5, U = 0.7555555555555555, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.58 seconds
# mu = -1.5, U = 1.4111111111111112, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.91 seconds
# mu = -1.5, U = 2.066666666666667, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.95 seconds
# mu = -1.5, U = 2.7222222222222223, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.35 seconds
# mu = -1.5, U = 3.3777777777777778, solution: [0.48461974 0.40456066 0.52397147]
# Time taken to solve the gap equation: 10.13 seconds
# mu = -1.5, U = 4.033333333333333, solution: [0.94118457 1.00197067 1.04239439]
# Time taken to solve the gap equation: 9.72 seconds
# mu = -1.5, U = 4.688888888888888, solution: [1.31743164 1.4953356  1.46269196]
# Time taken to solve the gap equation: 11.42 seconds
# mu = -1.5, U = 5.344444444444444, solution: [1.67775379 1.92820979 1.852037  ]
# Time taken to solve the gap equation: 10.55 seconds
# mu = -1.5, U = 6.0, solution: [2.03706262 2.33037077 2.22942467]
# Time taken to solve the gap equation: 10.34 seconds
# mu = -2, U = 0.1, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.86 seconds
# mu = -2, U = 0.7555555555555555, solution: [0.02930855 0.00243394 0.02689458]
# Time taken to solve the gap equation: 11.18 seconds
# mu = -2, U = 1.4111111111111112, solution: [0.14688344 0.02500049 0.13039501]
# Time taken to solve the gap equation: 9.96 seconds
# mu = -2, U = 2.066666666666667, solution: [0.32791243 0.08915373 0.29112004]
# Time taken to solve the gap equation: 9.84 seconds
# mu = -2, U = 2.7222222222222223, solution: [0.5520051  0.21767508 0.49996762]
# Time taken to solve the gap equation: 9.77 seconds
# mu = -2, U = 3.3777777777777778, solution: [0.81231406 0.44643004 0.76074803]
# Time taken to solve the gap equation: 10.22 seconds
# mu = -2, U = 4.033333333333333, solution: [1.10116447 0.80196105 1.07207575]
# Time taken to solve the gap equation: 10.73 seconds
# mu = -2, U = 4.688888888888888, solution: [1.40664779 1.23481404 1.41517504]
# Time taken to solve the gap equation: 10.60 seconds
# mu = -2, U = 5.344444444444444, solution: [1.72228841 1.67332187 1.77024083]
# Time taken to solve the gap equation: 10.64 seconds
# mu = -2, U = 6.0, solution: [2.04747905 2.09443557 2.12926898]
# Time taken to solve the gap equation: 10.34 seconds

# %%
beta_range = np.linspace(start=1, stop=10000, num=10)

mu = 0
V = 1
U = 2

gap_size_vs_beta = pd.DataFrame(columns=['beta', 'delta_0', 'delta_1', 'delta_2'], index=range(len(U_range)))
gap_size_vs_beta['beta'] = beta_range

for i, beta in enumerate(beta_range):
    egx_h = hamiltonians.EGXHamiltonian(t_gr=1, t_x=0.01, a=lattice_constant, V=V, mu=mu, U_gr=U, U_x=U)

    start = time.time()
    solution = hamiltonians.minimize_loop(beta=beta, k_points=BZ_grid, hamiltonian=egx_h)
    print(f'mu = {mu}, U = {U}, solution: {solution}')
    end = time.time()
    print(f'Time taken to solve the gap equation: {end - start:0.2f} seconds')
    gap_size_vs_beta.loc[i, ['delta_0', 'delta_1', 'delta_2']] = solution

gap_size_vs_beta.to_csv(f'gap_plots/gap_size_vs_beta_V_{V}_mu_{mu}.csv')
# Out:
# mu = 0, U = 2, solution: [0. 0. 0.]
# Time taken to solve the gap equation: 9.28 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [0.00494755 0.32957673 0.53616486]
# Time taken to solve the gap equation: 9.41 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [1.67247194e-04 3.19272522e-01 3.18765285e-01]
# Time taken to solve the gap equation: 9.73 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [1.73932725e-04 2.12904651e-01 2.13278285e-01]
# Time taken to solve the gap equation: 9.17 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [-1.81118295e-04  1.83873333e-01  1.53809916e-01]
# Time taken to solve the gap equation: 9.17 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [-7.67794415e-05  1.55509554e-01  1.20601223e-01]
# Time taken to solve the gap equation: 9.32 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [0.00065624 0.13948656 0.09824331]
# Time taken to solve the gap equation: 9.51 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [0.00054603 0.11932261 0.08393461]
# Time taken to solve the gap equation: 9.04 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [0.00074977 0.10432104 0.07349504]
# Time taken to solve the gap equation: 9.47 seconds
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# /Users/tjark/Projects/Research/quant-met/src/quant_met/hamiltonians/_free_energy.py:63: RuntimeWarning: overflow encountered in exp
#   np.sum(np.log(1 + np.nan_to_num(np.exp(-beta * bdg_energies))), axis=-1)
# mu = 0, U = 2, solution: [-9.28821235e-05  9.87213693e-02  6.38549726e-02]
# Time taken to solve the gap equation: 9.41 seconds
